# %%
from FLASH_OSIRIS_define import *
import sys
sys.path.append('../src')
# Out:
# yt : [INFO     ] 2025-06-03 14:34:35,742 Loading plugins from /home/dschneidinger/.config/yt/my_plugins.py

# %%
interface = FLASH_OSIRIS(
    FLASH_data="/home/dschneidinger/shared/data/VAC_DEREK3D_20um/MagShockZ_hdf5_chk_0006",
    inputfile_name="magshockz-v3.2-internal_fields-45deg",
    osiris_dims=1,
    reference_density=5e18,
    ppc=150,
    start_point=[0, 540],
    theta=np.pi/2,
    xmax = 7000,
    ion_mass_thresholds=[28,35],
    rqm_factor=10,
    # B_background=75000,
    dx_ndebye=7.14,
    # algorithm="cuda",
)
interface.save_instance()
interface.write_everything()
# Out:
# 2025-06-03 15:20:04,129 - FLASH_OSIRIS_define - INFO - Loading FLASH data from /home/dschneidinger/shared/data/VAC_DEREK3D_20um/MagShockZ_hdf5_chk_0006
# yt : [INFO     ] 2025-06-03 15:20:04,135 Particle file found: MagShockZ_hdf5_chk_0006
# yt : [INFO     ] 2025-06-03 15:20:04,153 Parameters: current_time              = 4.157630190965378e-09
# yt : [INFO     ] 2025-06-03 15:20:04,153 Parameters: domain_dimensions         = [384 496 384]
# yt : [INFO     ] 2025-06-03 15:20:04,154 Parameters: domain_left_edge          = [-0.8   -0.075 -0.8  ]
# yt : [INFO     ] 2025-06-03 15:20:04,154 Parameters: domain_right_edge         = [0.8 2.  0.8]
# yt : [INFO     ] 2025-06-03 15:20:04,154 Parameters: cosmological_simulation   = 0
# 2025-06-03 15:20:07,737 - FLASH_OSIRIS_define - INFO - ==================================================
# 2025-06-03 15:20:07,737 - FLASH_OSIRIS_define - INFO - INITIALIZING FLASH-OSIRIS INTERFACE
# 2025-06-03 15:20:07,737 - FLASH_OSIRIS_define - INFO - FLASH data: /home/dschneidinger/shared/data/VAC_DEREK3D_20um/MagShockZ_hdf5_chk_0006
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - Input file name: magshockz-v3.2-internal_fields-45deg.1d
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - Reference density: 5e+18 cm^-3
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - species_rqms: {'channel': 3810, 'sheathe': 6802, 'background': 7257, 'si': 3899}
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - all rqms will be divided by 10
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - External background magnetic field: 0 Gauss
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - OSIRIS dimensions: 1
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - Particles per cell: 100
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - Start point: [0, 540] [c/wpe]
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - Angle: 0.7853981633974483 (only used in 1D)
# 2025-06-03 15:20:07,738 - FLASH_OSIRIS_define - INFO - Xmax: 4600 (only used in 1D)
# 2025-06-03 15:20:07,739 - FLASH_OSIRIS_define - INFO - Output directory: /home/dschneidinger/MagShockZ/input_files/magshockz-v3.2-internal_fields-45deg.1d
# 2025-06-03 15:20:07,739 - FLASH_OSIRIS_define - INFO - INITIALIZING FLASH-OSIRIS INTERFACE COMPLETE
# 2025-06-03 15:20:07,739 - FLASH_OSIRIS_define - INFO - ==================================================
# Channel rqm: 1835
# 2025-06-03 15:20:10,893 - FLASH_OSIRIS_define - INFO - Debye length: 0.006562824201432289 osiris units
# 2025-06-03 15:20:10,893 - FLASH_OSIRIS_define - INFO - Background temperature: 22 eV
# 2025-06-03 15:20:12,877 - FLASH_OSIRIS_define - INFO - ********** real mass ratio: 7129.342627534372 dimensionless **********
# 2025-06-03 15:20:14,856 - FLASH_OSIRIS_define - INFO - Instance saved to /home/dschneidinger/MagShockZ/input_files/magshockz-v3.2-internal_fields-45deg.1d/instance.pkl
# 2025-06-03 15:20:14,857 - FLASH_OSIRIS_define - INFO - Processing edens with normalization 5.e+18
# 2025-06-03 15:20:17,026 - FLASH_OSIRIS_define - INFO - Processing Bx_int with normalization 7.172e+06
# 2025-06-03 15:20:17,342 - FLASH_OSIRIS_define - INFO - Processing By_int with normalization 7.172e+06
# 2025-06-03 15:20:19,330 - FLASH_OSIRIS_define - INFO - Processing Bz_int with normalization 7.172e+06
# 2025-06-03 15:20:21,308 - FLASH_OSIRIS_define - INFO - Processing magx with normalization 7.172e+06
# 2025-06-03 15:20:21,311 - FLASH_OSIRIS_define - INFO - Processing magy with normalization 7.172e+06
# 2025-06-03 15:20:21,314 - FLASH_OSIRIS_define - INFO - Processing magz with normalization 7.172e+06
# 2025-06-03 15:20:21,317 - FLASH_OSIRIS_define - INFO - Processing Ex with normalization 6.799e+16
# 2025-06-03 15:20:24,838 - FLASH_OSIRIS_define - INFO - Processing Ey with normalization 6.799e+16
# 2025-06-03 15:20:27,062 - FLASH_OSIRIS_define - INFO - Processing Ez with normalization 6.799e+16
# 2025-06-03 15:20:27,332 - FLASH_OSIRIS_define - INFO - Processing v_ix with normalization 9.480e+09
# 2025-06-03 15:20:28,809 - FLASH_OSIRIS_define - INFO - Processing v_iy with normalization 9.480e+09
# 2025-06-03 15:20:30,138 - FLASH_OSIRIS_define - INFO - Processing v_iz with normalization 9.480e+09
# 2025-06-03 15:20:31,320 - FLASH_OSIRIS_define - INFO - Processing v_ex with normalization 9.480e+09
# 2025-06-03 15:20:31,849 - FLASH_OSIRIS_define - INFO - Processing v_ey with normalization 9.480e+09
# 2025-06-03 15:20:32,377 - FLASH_OSIRIS_define - INFO - Processing v_ez with normalization 9.480e+09
# 2025-06-03 15:20:32,904 - FLASH_OSIRIS_define - INFO - Processing vthele with normalization 9.048e-04
# 2025-06-03 15:20:32,908 - FLASH_OSIRIS_define - INFO - Processing channeldens with normalization 5.e+18
# 2025-06-03 15:20:35,566 - FLASH_OSIRIS_define - INFO - Processing vthchannel with normalization 1.766e-02
# Channel rqm: 3810
# 2025-06-03 15:20:37,504 - FLASH_OSIRIS_define - INFO - Processing sheathedens with normalization 5.e+18
# 2025-06-03 15:20:37,745 - FLASH_OSIRIS_define - INFO - Processing vthsheathe with normalization 2.36e-02
# 2025-06-03 15:20:37,749 - FLASH_OSIRIS_define - INFO - Processing backgrounddens with normalization 5.e+18
# Sheathe rqm: 6945
# 2025-06-03 15:20:38,265 - FLASH_OSIRIS_define - INFO - Processing vthbackground with normalization 2.437e-02
# 2025-06-03 15:20:38,269 - FLASH_OSIRIS_define - INFO - Processing sidens with normalization 5.e+18
# Background rqm: 7412
# 2025-06-03 15:20:38,493 - FLASH_OSIRIS_define - INFO - Processing vthsi with normalization 1.787e-02
# 2025-06-03 15:20:38,497 - FLASH_OSIRIS_define - INFO - Electron thermal velocity bounds: [array(0.01156495), array(0.00655824)]
# 2025-06-03 15:20:38,498 - FLASH_OSIRIS_define - INFO - channel thermal velocity bounds: [array(0.00061177), array(0.00033794)]
# 2025-06-03 15:20:38,498 - FLASH_OSIRIS_define - INFO - sheathe thermal velocity bounds: [array(0.00045786), array(0.00025292)]
# 2025-06-03 15:20:38,499 - FLASH_OSIRIS_define - INFO - background thermal velocity bounds: [array(0.00044327), array(0.00024486)]
# 2025-06-03 15:20:38,499 - FLASH_OSIRIS_define - INFO - si thermal velocity bounds: [array(0.00060474), array(0.00033406)]
# 2025-06-03 15:20:38,499 - FLASH_OSIRIS_define - INFO - Writing OSIRIS input file to /home/dschneidinger/MagShockZ/input_files/magshockz-v3.2-internal_fields-45deg.1d/magshockz-v3.2-internal_fields-45deg.1d
# 2025-06-03 15:20:38,500 - FLASH_OSIRIS_define - INFO - OSIRIS input file written successfully
# 2025-06-03 15:20:38,500 - FLASH_OSIRIS_define - INFO - Instance saved to /home/dschneidinger/MagShockZ/input_files/magshockz-v3.2-internal_fields-45deg.1d/instance.pkl
# Silicon rqm: 3888
# Input file magshockz-v3.2-internal_fields-45deg.1d and python script input.py have been generated in /home/dschneidinger/MagShockZ/input_files/magshockz-v3.2-internal_fields-45deg.1d

# %%
interface.show_lineout_in_plane('edens')
lineouts = interface.plot_1D_lineout(['edens', 'channeldens', 'sheathedens', 'backgrounddens', 'sidens'])
mag_fields = interface.plot_1D_lineout(['Bx_int', 'By_int', 'Bz_int'])
ufl = interface.plot_1D_lineout(['v_ey','v_iy'])

# %%
import matplotlib.pyplot as plt
total = lineouts['sidens']+lineouts['backgrounddens']+lineouts['sheathedens']+lineouts['channeldens']
plt.plot(total - lineouts['edens'],label='total')
# plt.plot(lineouts['channeldens']/np.max(lineouts['channeldens']),label='channeldens')
# plt.plot(ufl['v_iy']/np.max(ufl['v_iy']),label='v_iy')
# plt.plot(ufl['v_ey']/np.max(ufl['v_ey']),label='v_ey')
# plt.plot(mag_fields['Bx_int']/np.max(mag_fields['Bx_int']),label='Bx_int')

plt.legend()

# %%
import yt

plt.imshow(interface.all_data['v_iy'][:,:,interface.all_data['v_ix'].shape[2]//2].T, origin='lower')

# %%
print(interface)
# Out:
# ==================================================
# FLASH-OSIRIS INTERFACE
# FLASH data: /home/dschneidinger/shared/data/VAC_DEREK3D_20um/MagShockZ_hdf5_chk_0006
# Input file name: magshockz-v3.2.1d-45degrees.1d
# Reference density: 5e+18 cm^-3
# species_rqms: {'channel': 3810, 'sheathe': 6802, 'background': 7257, 'si': 3899}
# all rqms will be divided by 10
# External background magnetic field: 75000 Gauss
# OSIRIS dimensions: 1
# Particles per cell: 100
# Start point: [0, 540] [c/wpe]Angle: 0.7853981633974483 (only used in 1D)Xmax: 4700 (only used in 1D)Output directory: /home/dschneidinger/MagShockZ/input_files/magshockz-v3.2.1d-45degrees.1d
# ==================================================
